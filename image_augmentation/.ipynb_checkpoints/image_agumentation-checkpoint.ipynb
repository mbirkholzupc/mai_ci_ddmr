# %%
import matplotlib.pyplot as plt
from skimage import data
import warnings
warnings.filterwarnings("ignore")

# %%
original_image = data.chelsea()

def show_images(before, after, op):
    fig, axes = plt.subplots(nrows=1, ncols=2)
    ax = axes.ravel()
    ax[0].imshow(before, cmap='gray')
    ax[0].set_title("Original image")

    ax[1].imshow(after, cmap='gray')
    ax[1].set_title(op + " image")
    if op == "Rescaled":
        ax[0].set_xlim(0, 400)
        ax[0].set_ylim(300, 0)
    else:        
        ax[0].axis('off')
        ax[1].axis('off')
    plt.tight_layout()

# %%
# Usage
from skimage.io import imread
import glob
folder_name= "test/benign"
img_format= "jpg"
images=glob.glob("./" + folder_name + "/*."+ img_format)

# %%
from ImageAugmentation import Augmentation
img=imread(images[0])/255

# %%
new = Augmentation(img)
plt.imshow(new)
plt.axis('off')
plt.show()

# %%
Aug_im=[]
for img_path in images:
    image = imread(img_path)
    Aug_im.append([Augmentation(image) for i in range(2)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-529a1c911496> in <module>()
#       2 for img_path in images:
#       3     image = imread(img_path)
# ----> 4     Aug_im.append([Augmentation(image) for i in range(2)])
#
# <ipython-input-108-529a1c911496> in <listcomp>(.0)
#       2 for img_path in images:
#       3     image = imread(img_path)
# ----> 4     Aug_im.append([Augmentation(image) for i in range(2)])
#
# /home/moxie/Desktop/CI/github/mai_ci_ddmr/image_augmentation/ImageAugmentation.py in Augmentation(image, Changes)
#     118     '''
#     119     for change in Changes:
# --> 120         image = change(image)
#     121     return image
#
# /home/moxie/Desktop/CI/github/mai_ci_ddmr/image_augmentation/ImageAugmentation.py in randomNoise(image)
#      59     return: image with random gaussian noise.
#      60     '''
# ...

# %%
Aug_img= ([augmentation.augment(img) for i in range(11)])

# %%
plt.imshow(Aug_im[3][1])
plt.axis('off')
plt.show()

# %%
# Image rescaling with sklearn.transform.rescale
import random
from skimage.transform import rescale

random=random.randrange(17, 200,10)/100
rescaled = rescale(img, random)
print(rescaled.shape)
print(random)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
data

# %%
# rescale image to 25% of the initial size
image_rescaled = rescale(original_image, 1.0 / 4.0)

show_images(original_image, image_rescaled, "Rescaled")

# %%
from skimage.color import rgb2gray

gray_scale_image = rgb2gray(original_image)

show_images(original_image, gray_scale_image, "Gray scale")

# %%
from skimage.transform import rotate

# perform a 45 degree rotation
image_with_rotation = rotate(original_image, 45)

show_images(original_image, image_with_rotation, "Rotated")

# %%
import numpy as np
from skimage import exposure

v_min, v_max = np.percentile(original_image, (0.2, 99.8))
better_contrast = exposure.rescale_intensity(original_image, in_range=(v_min, v_max))

show_images(original_image, better_contrast, 'Rescale intensity')

# %%
# gamma and gain parameters are between 0 and 1
adjusted_gamma_image = exposure.adjust_gamma(original_image, gamma=0.4, gain=0.9)

show_images(original_image, adjusted_gamma_image, 'Adjusted gamma')

# %%
log_correction_image = exposure.adjust_log(original_image)

show_images(original_image, log_correction_image, 'Logarithmic corrected')

# %%
sigmoid_correction_image = exposure.adjust_sigmoid(original_image)

show_images(original_image, log_correction_image, 'Sigmoid corrected')

# %%
horizontal_flip = original_image[:, ::-1]

show_images(original_image, horizontal_flip, 'Horizontal flip')

# %%
vertical_flip = original_image[::-1, :]

show_images(original_image, vertical_flip, 'vertical flip')

# %%
from scipy import ndimage

blured_image = ndimage.uniform_filter(original_image, size=(11, 11, 1))

show_images(original_image, blured_image, 'blurred')

# %%
file_list=[]
file_glob = os.path.join('images_aug', '*.jpg')
file_list.extend(gfile.Glob(file_glob))
c = 1

# %%
for image in file_list:
    img = cv2.imread(image)
    
    #rotacion 90 grados
    rows,cols,depth = img.shape        
    M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
    dst = cv2.warpAffine(img,M,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dst)
    c = c+1
    #rotacion 45 grados           
    N = cv2.getRotationMatrix2D((cols/2,rows/2),45,1)
    dstN = cv2.warpAffine(img,N,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstN)
    c = c+1
    #rotacion a 180 grados
    P = cv2.getRotationMatrix2D((cols/2,rows/2),180,1)
    dstP = cv2.warpAffine(img,P,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstP)
    c = c+1
    #rotacion a 25 grados
    Q = cv2.getRotationMatrix2D((cols/2,rows/2),25,1)
    dstQ= cv2.warpAffine(img,Q,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstQ)
    c = c+1
    #rotacion a 270 grados
    R = cv2.getRotationMatrix2D((cols/2,rows/2),270,1)
    dstR= cv2.warpAffine(img,R,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstR)
    c = c+1
    #rotacion 120 grados escalado 2
    rows,cols,depth = img.shape        
    D = cv2.getRotationMatrix2D((cols/2,rows/2),120,2)
    dstD = cv2.warpAffine(img,D,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstD)
    c = c+1
    #rotacion 120 grados escalado 0.5
    rows,cols,depth = img.shape        
    A = cv2.getRotationMatrix2D((cols/2,rows/2),130,0.5)
    dstA = cv2.warpAffine(img,A,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstA)
    c = c+1
    #rotacion 75 grados  escalado 2         
    C = cv2.getRotationMatrix2D((cols/2,rows/2),75,2)
    dstC = cv2.warpAffine(img,C,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstC)
    c = c+1
    #rotacion a 180 grados escalado 2
    B = cv2.getRotationMatrix2D((cols/2,rows/2),210,2)
    dstB = cv2.warpAffine(img,B,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstB)
    c = c+1
    #rotacion a 55 grados escalado 2
    D = cv2.getRotationMatrix2D((cols/2,rows/2),55,2)
    dstD = cv2.warpAffine(img,D,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstD)
    c = c+1
    #rotacion a 300 grados escalado 2
    E = cv2.getRotationMatrix2D((cols/2,rows/2),300,2)
    dstE= cv2.warpAffine(img,E,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstE)
    c = c+1
    #rotacion 75 grados  escalado 0.5         
    C = cv2.getRotationMatrix2D((cols/2,rows/2),75,0.5)
    dstC = cv2.warpAffine(img,C,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstC)
    c = c+1
    #rotacion a 180 grados escalado 0.5
    B = cv2.getRotationMatrix2D((cols/2,rows/2),210,0.5)
    dstB = cv2.warpAffine(img,B,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstB)
    c = c+1
    #rotacion a 55 grados escalado 0.5
    D = cv2.getRotationMatrix2D((cols/2,rows/2),55,0.5)
    dstD = cv2.warpAffine(img,D,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstD)
    c = c+1
    #rotacion a 300 grados escalado 0.5
    E = cv2.getRotationMatrix2D((cols/2,rows/2),300,0.5)
    dstE= cv2.warpAffine(img,E,(cols,rows))
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',dstE)
    c = c+1
    #borroneo gaussiano original
    blur = cv2.GaussianBlur(img,(9,9),0)
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',blur)
    c = c+1
    #gaussian blur rotation 55 degrees scale 0.5
    blur = cv2.GaussianBlur(dstD,(9,9),0)
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',blur)
    c = c+1
    #distribution normal gaussian noise 
    noise = np.zeros(img.shape)
    m = (0,0,0)
    s = (99,99,99)    
    cv2.randn(noise,m,s)
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',noise+img)
    c = c+1
    #uniform distribution gaussian noise 
    noise1 = np.zeros(img.shape)       
    cv2.randu(noise1,m,s)
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',noise1+img)
    c = c+1
    #laplacian
    laplacian = cv2.Laplacian(img,cv2.CV_64F)
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',laplacian+img)
    c = c+1
    #flip vertical
    flipup = cv2.flip(img,1)
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',flipup)
    c = c+1
    #flip horizontal
    fliphor = cv2.flip(img,0)
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',fliphor)
    c = c+1
    #flip both
    flipboth = cv2.flip(img,-1)
    cv2.imwrite('images_aug\image_'+ str(c) + '.jpg',flipboth)
    c = c+1
